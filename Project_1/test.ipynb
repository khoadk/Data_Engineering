# %%
# %load_ext sql

# %%
# %sql postgresql://student:student@127.0.0.1/sparkifydb
# Out:
# 'Connected: student@sparkifydb'

# %%
# %sql SELECT * FROM songplays LIMIT 5;
# Out:
#  * postgresql://student:***@127.0.0.1/sparkifydb
# 5 rows affected.
# [('28', datetime.datetime(2018, 11, 14, 3, 26, 35, 796000), '80', 'free', None, None, '548', 'Portland-South Portland, ME', '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"'),
#  ('7', datetime.datetime(2018, 11, 14, 0, 29, 22, 796000), '95', 'paid', None, None, '411', 'Winston-Salem, NC', '"Mozilla/5.0 (iPhone; CPU iPhone OS 7_1_2 like Mac OS X) AppleWebKit/537.51.2 (KHTML, like Gecko) Version/7.0 Mobile/11D257 Safari/9537.53"'),
#  ('12', datetime.datetime(2018, 11, 14, 0, 44, 24, 796000), '95', 'paid', None, None, '411', 'Winston-Salem, NC', '"Mozilla/5.0 (iPhone; CPU iPhone OS 7_1_2 like Mac OS X) AppleWebKit/537.51.2 (KHTML, like Gecko) Version/7.0 Mobile/11D257 Safari/9537.53"'),
# ...

# %%
# %sql SELECT * FROM users LIMIT 5;
# Out:
#  * postgresql://student:***@127.0.0.1/sparkifydb
# 5 rows affected.
# [('99', 'Ann', 'Banks', 'F', 'free'),
#  ('59', 'Lily', 'Cooper', 'F', 'free'),
#  ('95', 'Sara', 'Johnson', 'F', 'paid'),
#  ('9', 'Wyatt', 'Scott', 'M', 'free'),
#  ('10', 'Sylvie', 'Cruz', 'F', 'free')]

# %%
# %sql SELECT * FROM songs LIMIT 5;
# Out:
#  * postgresql://student:***@127.0.0.1/sparkifydb
# 5 rows affected.
# [('SOMZWCG12A8C13C480', "I Didn't Mean To", 'ARD7TVE1187B99BFB1', 0, Decimal('218.93179')),
#  ('SOQHXMF12AB0182363', 'Young Boy Blues', 'ARGSJW91187B9B1D6B', 0, Decimal('218.77506')),
#  ('SOXVLOJ12AB0189215', 'Amor De Cabaret', 'ARKRRTF1187B9984DA', 0, Decimal('177.47546')),
#  ('SOYMRWW12A6D4FAB14', 'The Moon And I (Ordinary Day Album Version)', 'ARKFYS91187B98E58F', 0, Decimal('267.7024')),
#  ('SOUDSGM12AC9618304', 'Insatiable (Instrumental Version)', 'ARNTLGG11E2835DDB9', 0, Decimal('266.39628'))]

# %%
# %sql SELECT * FROM artists LIMIT 5;
# Out:
#  * postgresql://student:***@127.0.0.1/sparkifydb
# 5 rows affected.
# [('ARD7TVE1187B99BFB1', 'Casual', 'California - LA', Decimal('NaN'), Decimal('NaN')),
#  ('ARGSJW91187B9B1D6B', 'JennyAnyKind', 'North Carolina', Decimal('35.21962'), Decimal('-80.01955')),
#  ('ARKRRTF1187B9984DA', 'Sonora Santanera', '', Decimal('NaN'), Decimal('NaN')),
#  ('ARKFYS91187B98E58F', 'Jeff And Sheri Easter', '', Decimal('NaN'), Decimal('NaN')),
#  ('ARNTLGG11E2835DDB9', 'Clp', '', Decimal('NaN'), Decimal('NaN'))]

# %%
# %sql SELECT * FROM time LIMIT 5;
# Out:
#  * postgresql://student:***@127.0.0.1/sparkifydb
# 5 rows affected.
# [(datetime.datetime(2018, 11, 14, 0, 3, 22, 796000), 0, 14, 46, 11, 2018, 'Wednesday'),
#  (datetime.datetime(2018, 11, 14, 0, 6, 8, 796000), 0, 14, 46, 11, 2018, 'Wednesday'),
#  (datetime.datetime(2018, 11, 14, 0, 11, 6, 796000), 0, 14, 46, 11, 2018, 'Wednesday'),
#  (datetime.datetime(2018, 11, 14, 0, 17, 37, 796000), 0, 14, 46, 11, 2018, 'Wednesday'),
#  (datetime.datetime(2018, 11, 14, 0, 20, 25, 796000), 0, 14, 46, 11, 2018, 'Wednesday')]

# %% [markdown]
# ## REMEMBER: Restart this notebook to close connection to `sparkifydb`
# Each time you run the cells above, remember to restart this notebook to close the connection to your database. Otherwise, you won't be able to run your code in `create_tables.py`, `etl.py`, or `etl.ipynb` files since you can't make multiple connections to the same database (in this case, sparkifydb).

# %%
# %sql SELECT * FROM songplays WHERE song_id is not  null limit 20;
# Out:
#  * postgresql://student:***@127.0.0.1/sparkifydb
# 0 rows affected.
# []

# %%
# %sql SELECT songs.song_id, songs.artist_id, songs.title, songs.duration, artists.name FROM songs, artists WHERE songs.artist_id = artists.artist_id
# Out:
#  * postgresql://student:***@127.0.0.1/sparkifydb
# 71 rows affected.
# [('SOMZWCG12A8C13C480', 'ARD7TVE1187B99BFB1', "I Didn't Mean To", Decimal('218.93179'), 'Casual'),
#  ('SOQHXMF12AB0182363', 'ARGSJW91187B9B1D6B', 'Young Boy Blues', Decimal('218.77506'), 'JennyAnyKind'),
#  ('SOXVLOJ12AB0189215', 'ARKRRTF1187B9984DA', 'Amor De Cabaret', Decimal('177.47546'), 'Sonora Santanera'),
#  ('SOYMRWW12A6D4FAB14', 'ARKFYS91187B98E58F', 'The Moon And I (Ordinary Day Album Version)', Decimal('267.7024'), 'Jeff And Sheri Easter'),
#  ('SOUDSGM12AC9618304', 'ARNTLGG11E2835DDB9', 'Insatiable (Instrumental Version)', Decimal('266.39628'), 'Clp'),
#  ('SOIAZJW12AB01853F1', 'AR8ZCNI1187B9A069B', 'Pink World', Decimal('269.81832'), 'Planet P Project'),
#  ('SOMJBYD12A6D4F8557', 'ARD0S291187B9B7BF5', 'Keepin It Real (Skit)', Decimal('114.78159'), 'Rated R'),
#  ('SOHKNRJ12A6701D1F8', 'AR10USD1187B99F3F1', 'Drop of Rain', Decimal('189.57016'), 'Tweeterfriendly Music'),
# ...

# %%
# %sql SELECT songs.song_id, songs.artist_id, songs.title, songs.duration, artists.name \
FROM songs, artists \
WHERE songs.artist_id = artists.artist_id
# Out:
#  * postgresql://student:***@127.0.0.1/sparkifydb
# 71 rows affected.
# [('SOMZWCG12A8C13C480', 'ARD7TVE1187B99BFB1', "I Didn't Mean To", Decimal('218.93179'), 'Casual'),
#  ('SOQHXMF12AB0182363', 'ARGSJW91187B9B1D6B', 'Young Boy Blues', Decimal('218.77506'), 'JennyAnyKind'),
#  ('SOXVLOJ12AB0189215', 'ARKRRTF1187B9984DA', 'Amor De Cabaret', Decimal('177.47546'), 'Sonora Santanera'),
#  ('SOYMRWW12A6D4FAB14', 'ARKFYS91187B98E58F', 'The Moon And I (Ordinary Day Album Version)', Decimal('267.7024'), 'Jeff And Sheri Easter'),
#  ('SOUDSGM12AC9618304', 'ARNTLGG11E2835DDB9', 'Insatiable (Instrumental Version)', Decimal('266.39628'), 'Clp'),
#  ('SOIAZJW12AB01853F1', 'AR8ZCNI1187B9A069B', 'Pink World', Decimal('269.81832'), 'Planet P Project'),
#  ('SOMJBYD12A6D4F8557', 'ARD0S291187B9B7BF5', 'Keepin It Real (Skit)', Decimal('114.78159'), 'Rated R'),
#  ('SOHKNRJ12A6701D1F8', 'AR10USD1187B99F3F1', 'Drop of Rain', Decimal('189.57016'), 'Tweeterfriendly Music'),
# ...
